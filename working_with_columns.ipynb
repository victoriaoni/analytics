# %% [markdown]
# <a href="https://colab.research.google.com/github/victoriaoni/analytics/blob/main/working_with_columns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Working with columns
# - Creating
# - Reading
# - Updating
# - Deleting

# %%
import pandas as pd

# %%
df = pd.read_csv('/example.csv')

# %%
df.head()
# Out:
#      Name  Age      City  Experience
# 0    John   29    London        15.0
# 1    Mark   24     Abuja         NaN
# 2   Vicky   28     Tokyo        14.0
# 3  Daniel   31   Toronto        11.0
# 4    Bola   33  New York        13.0

# %%
# getting a list of all column names --> df.columns
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'Experience'], dtype='object')

# %%
# Read (Access) columns df[ ['Age'] ]
#df[ ['Age', 'City', 'Experience'] ]

sel_cols = ['Name', 'Age', 'Experience']

sel_col_df = df[sel_cols]

# %%
sel_col_df

# %%
df
# Out:
#      Name  Age      City  Experience
# 0    John   29    London        15.0
# 1    Mark   24     Abuja         NaN
# 2   Vicky   28     Tokyo        14.0
# 3  Daniel   31   Toronto        11.0
# 4    Bola   33  New York        13.0
# 5     Sam   31    Sydney        13.0
# 6   Lizzy   32     Paris        13.0

# %%
# col with single value 
df['Sal'] = 25000

# %%
df
# Out:
#      Name  Age      City  Experience    Sal
# 0    John   29    London        15.0  25000
# 1    Mark   24     Abuja         NaN  25000
# 2   Vicky   28     Tokyo        14.0  25000
# 3  Daniel   31   Toronto        11.0  25000
# 4    Bola   33  New York        13.0  25000
# 5     Sam   31    Sydney        13.0  25000
# 6   Lizzy   32     Paris        13.0  25000

# %%
salaries = [20000, 25000, 30000, 35000, 40000, 450000, 50000]
df['Salary'] = salaries

# %%
df
# Out:
#      Name  Age      City  Experience    Sal  Salary
# 0    John   29    London        15.0  25000   20000
# 1    Mark   24     Abuja         NaN  25000   25000
# 2   Vicky   28     Tokyo        14.0  25000   30000
# 3  Daniel   31   Toronto        11.0  25000   35000
# 4    Bola   33  New York        13.0  25000   40000
# 5     Sam   31    Sydney        13.0  25000  450000
# 6   Lizzy   32     Paris        13.0  25000   50000

# %%
# creating cols from existing cols
df['Username'] = df['Name'] + '_' + df['City']

# %%
df
# Out:
#      Name  Age      City  Experience    Sal  Salary        Username
# 0    John   29    London        15.0  25000   20000     John_London
# 1    Mark   24     Abuja         NaN  25000   25000      Mark_Abuja
# 2   Vicky   28     Tokyo        14.0  25000   30000     Vicky_Tokyo
# 3  Daniel   31   Toronto        11.0  25000   35000  Daniel_Toronto
# 4    Bola   33  New York        13.0  25000   40000   Bola_New York
# 5     Sam   31    Sydney        13.0  25000  450000      Sam_Sydney
# 6   Lizzy   32     Paris        13.0  25000   50000     Lizzy_Paris

# %%
df.columns
# Out:
# Index(['name', 'age', 'city', 'experience', 'sal', 'salary', 'username',
#        'ethnic background'],
#       dtype='object')

# %%
# change cols to lowercase
# removing white spaces --> 'Full_Name'
# renaming cols

df['Ethnic Background'] = ['Brit', 'Black', 'Carb', 'Afr', 'Cauc', 'Asian', 'Latino']

# %%
df
# Out:
#      Name  Age      City  Experience    Sal  Salary        Username  \
# 0    John   29    London        15.0  25000   20000     John_London
# 1    Mark   24     Abuja         NaN  25000   25000      Mark_Abuja
# 2   Vicky   28     Tokyo        14.0  25000   30000     Vicky_Tokyo
# 3  Daniel   31   Toronto        11.0  25000   35000  Daniel_Toronto
# 4    Bola   33  New York        13.0  25000   40000   Bola_New York
# 5     Sam   31    Sydney        13.0  25000  450000      Sam_Sydney
# 6   Lizzy   32     Paris        13.0  25000   50000     Lizzy_Paris
#
#   Ethnic Background
# 0              Brit
# 1             Black
# 2              Carb
# 3               Afr
# 4              Cauc
# 5             Asian
# 6            Latino

# %%
df_columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['name', 'age', 'city', 'experience', 'sal', 'salary', 'username',
#        'ethnic background'],
#       dtype='object')

# %%
df.shape
# Out:
# (7, 8)

# %%
df.size
# Out:
# 56

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# removing white spaces --> 'Full_Name'
df
# Out:
#      name  age      city  experience    sal  salary        username  \
# 0    John   29    London        15.0  25000   20000     John_London
# 1    Mark   24     Abuja         NaN  25000   25000      Mark_Abuja
# 2   Vicky   28     Tokyo        14.0  25000   30000     Vicky_Tokyo
# 3  Daniel   31   Toronto        11.0  25000   35000  Daniel_Toronto
# 4    Bola   33  New York        13.0  25000   40000   Bola_New York
# 5     Sam   31    Sydney        13.0  25000  450000      Sam_Sydney
# 6   Lizzy   32     Paris        13.0  25000   50000     Lizzy_Paris
#
#   ethnic background
# 0              Brit
# 1             Black
# 2              Carb
# 3               Afr
# 4              Cauc
# 5             Asian
# 6            Latino

# %%
df['educational Background'] = 'Graduate'

# %%
df
# Out:
#      name  age      city  experience    sal  salary        username  \
# 0    John   29    London        15.0  25000   20000     John_London
# 1    Mark   24     Abuja         NaN  25000   25000      Mark_Abuja
# 2   Vicky   28     Tokyo        14.0  25000   30000     Vicky_Tokyo
# 3  Daniel   31   Toronto        11.0  25000   35000  Daniel_Toronto
# 4    Bola   33  New York        13.0  25000   40000   Bola_New York
# 5     Sam   31    Sydney        13.0  25000  450000      Sam_Sydney
# 6   Lizzy   32     Paris        13.0  25000   50000     Lizzy_Paris
#
#   ethnic background educational Background
# 0              Brit               Graduate
# 1             Black               Graduate
# 2              Carb               Graduate
# 3               Afr               Graduate
# 4              Cauc               Graduate
# 5             Asian               Graduate
# 6            Latino               Graduate

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['name', 'age', 'city', 'experience', 'sal', 'salary', 'username',
#        'ethnic_background', 'educational_Background'],
#       dtype='object')

# %%
df.rename({'experience':'years_of_experience'}, axis=1)
# Out:
#      name  age      city  years_of_experience    sal  salary        username  \
# 0    John   29    London                 15.0  25000   20000     John_London
# 1    Mark   24     Abuja                  NaN  25000   25000      Mark_Abuja
# 2   Vicky   28     Tokyo                 14.0  25000   30000     Vicky_Tokyo
# 3  Daniel   31   Toronto                 11.0  25000   35000  Daniel_Toronto
# 4    Bola   33  New York                 13.0  25000   40000   Bola_New York
# 5     Sam   31    Sydney                 13.0  25000  450000      Sam_Sydney
# 6   Lizzy   32     Paris                 13.0  25000   50000     Lizzy_Paris
#
#   ethnic_background educational_Background
# 0              Brit               Graduate
# 1             Black               Graduate
# 2              Carb               Graduate
# 3               Afr               Graduate
# 4              Cauc               Graduate
# 5             Asian               Graduate
# 6            Latino               Graduate

# %%
# deleting (dropping) columns
df.drop(columns='sal', inplace=True)
# Out:
#      name  age      city  experience  salary        username  \
# 0    John   29    London        15.0   20000     John_London
# 1    Mark   24     Abuja         NaN   25000      Mark_Abuja
# 2   Vicky   28     Tokyo        14.0   30000     Vicky_Tokyo
# 3  Daniel   31   Toronto        11.0   35000  Daniel_Toronto
# 4    Bola   33  New York        13.0   40000   Bola_New York
# 5     Sam   31    Sydney        13.0  450000      Sam_Sydney
# 6   Lizzy   32     Paris        13.0   50000     Lizzy_Paris
#
#   ethnic_background educational_Background
# 0              Brit               Graduate
# 1             Black               Graduate
# 2              Carb               Graduate
# 3               Afr               Graduate
# 4              Cauc               Graduate
# 5             Asian               Graduate
# 6            Latino               Graduate

# %%
df
# Out:
#      name  age      city  experience    sal  salary        username  \
# 0    John   29    London        15.0  25000   20000     John_London
# 1    Mark   24     Abuja         NaN  25000   25000      Mark_Abuja
# 2   Vicky   28     Tokyo        14.0  25000   30000     Vicky_Tokyo
# 3  Daniel   31   Toronto        11.0  25000   35000  Daniel_Toronto
# 4    Bola   33  New York        13.0  25000   40000   Bola_New York
# 5     Sam   31    Sydney        13.0  25000  450000      Sam_Sydney
# 6   Lizzy   32     Paris        13.0  25000   50000     Lizzy_Paris
#
#   ethnic_background educational_Background
# 0              Brit               Graduate
# 1             Black               Graduate
# 2              Carb               Graduate
# 3               Afr               Graduate
# 4              Cauc               Graduate
# 5             Asian               Graduate
# 6            Latino               Graduate

# %% [markdown]
# ## conclusion

# %%
# df.columns --> to get the labels of the columns
# create columns --> df['colname'] = value
# read (access) columns ---> df['colname']
# update ---> df.rename({'old name': 'new_name'}), df.columns.str.lower(), df.columns.str.replace('old', 'new')

# %%
import pandas as pd
sales_df = pd.read_csv('/content/SuperStoreOrders.csv')

# %%
pd.set_option()

# %%
sales_df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
sales_df.head(2)
# Out:
#         order_id  order_date   ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040  01/01/2011  06/01/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883  01/01/2011  08/01/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ...  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category              product_name sales quantity  \
# 0  Office Supplies      Storage       Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies  Acme Trimmer, High Speed   120        3
#
#    discount   profit  shipping_cost  order_priority  year
# 0       0.0  106.140          35.46          Medium  2011
# 1       0.1   36.036           9.72          Medium  2011
#
# [2 rows x 21 columns]

# %%
sales_df.shape
# Out:
# (51290, 21)

# %%
sales_df['state']
# Out:
# 0             Constantine
# 1         New South Wales
# 2                Budapest
# 3               Stockholm
# 4         New South Wales
#                ...
# 51285          California
# 51286    Souss-Massa-Draâ
# 51287             Managua
# 51288           Chihuahua
# 51289            Colorado
# Name: state, Length: 51290, dtype: object

# %%
sales_df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
sales_df[['country', 'sales', 'market', 'region']].head(100)
# Out:
#         country sales  market          region
# 0       Algeria   408  Africa          Africa
# 1     Australia   120    APAC         Oceania
# 2       Hungary    66    EMEA            EMEA
# 3        Sweden    45      EU           North
# 4     Australia   114    APAC         Oceania
# ..          ...   ...     ...             ...
# 95      Vietnam   124    APAC  Southeast Asia
# 96  Philippines    52    APAC  Southeast Asia
# 97      Vietnam    45    APAC  Southeast Asia
# 98  Philippines     9    APAC  Southeast Asia
# 99      Vietnam    10    APAC  Southeast Asia
#
# [100 rows x 4 columns]

# %%
sales_df.rename({'shipping_cost': 'shipping'}, axis=1).head(2)
# Out:
#         order_id  order_date   ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040  01/01/2011  06/01/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883  01/01/2011  08/01/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ...  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category              product_name sales quantity  \
# 0  Office Supplies      Storage       Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies  Acme Trimmer, High Speed   120        3
#
#    discount   profit  shipping  order_priority  year
# 0       0.0  106.140     35.46          Medium  2011
# 1       0.1   36.036      9.72          Medium  2011
#
# [2 rows x 21 columns]

# %%
sales_df.rename({'quantity':'qty'}, axis='columns').head(2)
# Out:
#         order_id  order_date   ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040  01/01/2011  06/01/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883  01/01/2011  08/01/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ...  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category              product_name sales qty  discount  \
# 0  Office Supplies      Storage       Tenex Lockers, Blue   408   2       0.0
# 1  Office Supplies     Supplies  Acme Trimmer, High Speed   120   3       0.1
#
#     profit  shipping_cost  order_priority  year
# 0  106.140          35.46          Medium  2011
# 1   36.036           9.72          Medium  2011
#
# [2 rows x 21 columns]
